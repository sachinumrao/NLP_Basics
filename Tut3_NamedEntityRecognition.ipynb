# %% [markdown]
# ### Import dependencies to use NLTK

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
demo1 = """
Samsung told owners of its Galaxy Note 4 phone to install a new version of Google’s Android operating system intended for the more recent Galaxy Note 7, but which users claimed rendered the old model sluggish.

Likewise, Apple told iPhone 6 owners to install an operating system designed for the iPhone 7, leading to problems for owners of the older model.

Both firms were issued the maximum fine of €5m each and ordered to display a notice on their Italian websites informing customers of the watchdog’s decision.

Apple was fined an additional €5m for failing to give customers clear information about “essential” characteristics of lithium batteries, including their average life expectancy, how to maintain them or eventually replace them in the firm’s iPhones.
"""

# %% [markdown]
# ### Tokenize the sentences into words and perform part of speech tagging

# %%
def preprocess_v1(text):
    word_list = nltk.word_tokenize(text)
    word_tags = nltk.pos_tag(word_list)
    return word_list, word_tags

# %%
l1, t1 = preprocess_v1(demo1)

# %%
l1
# Out:
# ['Samsung',
#  'told',
#  'owners',
#  'of',
#  'its',
#  'Galaxy',
#  'Note',
#  '4',
#  'phone',
#  'to',
#  'install',
#  'a',
#  'new',
#  'version',
#  'of',
#  'Google',
#  '’',
#  's',
#  'Android',
#  'operating',
#  'system',
#  'intended',
#  'for',
#  'the',
#  'more',
#  'recent',
#  'Galaxy',
#  'Note',
#  '7',
#  ',',
#  'but',
#  'which',
#  'users',
#  'claimed',
#  'rendered',
#  'the',
#  'old',
#  'model',
#  'sluggish',
#  '.',
#  'Likewise',
#  ',',
#  'Apple',
#  'told',
#  'iPhone',
#  '6',
#  'owners',
#  'to',
#  'install',
#  'an',
#  'operating',
#  'system',
#  'designed',
#  'for',
#  'the',
#  'iPhone',
#  '7',
#  ',',
#  'leading',
#  'to',
#  'problems',
#  'for',
#  'owners',
#  'of',
#  'the',
#  'older',
#  'model',
#  '.',
#  'Both',
#  'firms',
#  'were',
#  'issued',
#  'the',
#  'maximum',
#  'fine',
#  'of',
#  '€5m',
#  'each',
#  'and',
#  'ordered',
#  'to',
#  'display',
#  'a',
#  'notice',
#  'on',
#  'their',
#  'Italian',
#  'websites',
#  'informing',
#  'customers',
#  'of',
#  'the',
#  'watchdog',
#  '’',
#  's',
#  'decision',
#  '.',
#  'Apple',
#  'was',
#  'fined',
#  'an',
#  'additional',
#  '€5m',
#  'for',
#  'failing',
#  'to',
#  'give',
#  'customers',
#  'clear',
#  'information',
#  'about',
#  '“',
#  'essential',
#  '”',
#  'characteristics',
#  'of',
#  'lithium',
#  'batteries',
#  ',',
#  'including',
#  'their',
#  'average',
#  'life',
#  'expectancy',
#  ',',
#  'how',
#  'to',
#  'maintain',
#  'them',
#  'or',
#  'eventually',
#  'replace',
#  'them',
#  'in',
#  'the',
#  'firm',
#  '’',
#  's',
#  'iPhones',
#  '.']

# %%
t1
# Out:
# [('Samsung', 'NNP'),
#  ('told', 'VBD'),
#  ('owners', 'NNS'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('Galaxy', 'NNP'),
#  ('Note', 'NNP'),
#  ('4', 'CD'),
#  ('phone', 'NN'),
#  ('to', 'TO'),
#  ('install', 'VB'),
#  ('a', 'DT'),
#  ('new', 'JJ'),
#  ('version', 'NN'),
#  ('of', 'IN'),
#  ('Google', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('Android', 'NNP'),
#  ('operating', 'VBG'),
#  ('system', 'NN'),
#  ('intended', 'VBN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('more', 'RBR'),
#  ('recent', 'JJ'),
#  ('Galaxy', 'NNP'),
#  ('Note', 'NNP'),
#  ('7', 'CD'),
#  (',', ','),
#  ('but', 'CC'),
#  ('which', 'WDT'),
#  ('users', 'NNS'),
#  ('claimed', 'VBD'),
#  ('rendered', 'VBD'),
#  ('the', 'DT'),
#  ('old', 'JJ'),
#  ('model', 'NN'),
#  ('sluggish', 'JJ'),
#  ('.', '.'),
#  ('Likewise', 'NNP'),
#  (',', ','),
#  ('Apple', 'NNP'),
#  ('told', 'VBD'),
#  ('iPhone', 'NN'),
#  ('6', 'CD'),
#  ('owners', 'NNS'),
#  ('to', 'TO'),
#  ('install', 'VB'),
#  ('an', 'DT'),
#  ('operating', 'NN'),
#  ('system', 'NN'),
#  ('designed', 'VBN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('iPhone', 'NN'),
#  ('7', 'CD'),
#  (',', ','),
#  ('leading', 'VBG'),
#  ('to', 'TO'),
#  ('problems', 'NNS'),
#  ('for', 'IN'),
#  ('owners', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('older', 'JJR'),
#  ('model', 'NN'),
#  ('.', '.'),
#  ('Both', 'DT'),
#  ('firms', 'NNS'),
#  ('were', 'VBD'),
#  ('issued', 'VBN'),
#  ('the', 'DT'),
#  ('maximum', 'JJ'),
#  ('fine', 'NN'),
#  ('of', 'IN'),
#  ('€5m', 'NNP'),
#  ('each', 'DT'),
#  ('and', 'CC'),
#  ('ordered', 'VBD'),
#  ('to', 'TO'),
#  ('display', 'VB'),
#  ('a', 'DT'),
#  ('notice', 'NN'),
#  ('on', 'IN'),
#  ('their', 'PRP$'),
#  ('Italian', 'JJ'),
#  ('websites', 'NNS'),
#  ('informing', 'VBG'),
#  ('customers', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('watchdog', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('decision', 'NN'),
#  ('.', '.'),
#  ('Apple', 'NNP'),
#  ('was', 'VBD'),
#  ('fined', 'VBN'),
#  ('an', 'DT'),
#  ('additional', 'JJ'),
#  ('€5m', 'NN'),
#  ('for', 'IN'),
#  ('failing', 'VBG'),
#  ('to', 'TO'),
#  ('give', 'VB'),
#  ('customers', 'NNS'),
#  ('clear', 'JJ'),
#  ('information', 'NN'),
#  ('about', 'IN'),
#  ('“', 'NNP'),
#  ('essential', 'JJ'),
#  ('”', 'NNP'),
#  ('characteristics', 'NNS'),
#  ('of', 'IN'),
#  ('lithium', 'NN'),
#  ('batteries', 'NNS'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('their', 'PRP$'),
#  ('average', 'JJ'),
#  ('life', 'NN'),
#  ('expectancy', 'NN'),
#  (',', ','),
#  ('how', 'WRB'),
#  ('to', 'TO'),
#  ('maintain', 'VB'),
#  ('them', 'PRP'),
#  ('or', 'CC'),
#  ('eventually', 'RB'),
#  ('replace', 'VB'),
#  ('them', 'PRP'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('firm', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('iPhones', 'NNS'),
#  ('.', '.')]

# %%
#Noun preceeded by adjectives and determinant is considered Named Entity
pattern = 'NP: {<DT>?<JJ>*<NN>}'

# %%
cp = nltk.RegexpParser(pattern)
cs = cp.parse(t1)
print(cs)
# Out:
# (S
#   Samsung/NNP
#   told/VBD
#   owners/NNS
#   of/IN
#   its/PRP$
#   Galaxy/NNP
#   Note/NNP
#   4/CD
#   (NP phone/NN)
#   to/TO
#   install/VB
#   (NP a/DT new/JJ version/NN)
#   of/IN
#   Google/NNP
#   ’/NNP
#   s/VBD
#   Android/NNP
#   operating/VBG
#   (NP system/NN)
#   intended/VBN
#   for/IN
#   the/DT
#   more/RBR
#   recent/JJ
#   Galaxy/NNP
#   Note/NNP
#   7/CD
#   ,/,
#   but/CC
#   which/WDT
#   users/NNS
#   claimed/VBD
#   rendered/VBD
#   (NP the/DT old/JJ model/NN)
#   sluggish/JJ
#   ./.
#   Likewise/NNP
#   ,/,
#   Apple/NNP
#   told/VBD
#   (NP iPhone/NN)
#   6/CD
#   owners/NNS
#   to/TO
#   install/VB
#   (NP an/DT operating/NN)
#   (NP system/NN)
#   designed/VBN
#   for/IN
#   (NP the/DT iPhone/NN)
#   7/CD
#   ,/,
#   leading/VBG
#   to/TO
#   problems/NNS
#   for/IN
#   owners/NNS
#   of/IN
#   the/DT
#   older/JJR
#   (NP model/NN)
#   ./.
#   Both/DT
#   firms/NNS
#   were/VBD
#   issued/VBN
#   (NP the/DT maximum/JJ fine/NN)
#   of/IN
#   €5m/NNP
#   each/DT
#   and/CC
#   ordered/VBD
#   to/TO
#   display/VB
#   (NP a/DT notice/NN)
#   on/IN
#   their/PRP$
#   Italian/JJ
#   websites/NNS
#   informing/VBG
#   customers/NNS
#   of/IN
#   (NP the/DT watchdog/NN)
#   ’/NNP
#   (NP s/NN)
#   (NP decision/NN)
#   ./.
#   Apple/NNP
#   was/VBD
#   fined/VBN
#   (NP an/DT additional/JJ €5m/NN)
#   for/IN
#   failing/VBG
#   to/TO
#   give/VB
#   customers/NNS
#   (NP clear/JJ information/NN)
#   about/IN
#   “/NNP
#   essential/JJ
#   ”/NNP
#   characteristics/NNS
#   of/IN
#   (NP lithium/NN)
#   batteries/NNS
#   ,/,
#   including/VBG
#   their/PRP$
#   (NP average/JJ life/NN)
#   (NP expectancy/NN)
#   ,/,
#   how/WRB
#   to/TO
#   maintain/VB
#   them/PRP
#   or/CC
#   eventually/RB
#   replace/VB
#   them/PRP
#   in/IN
#   (NP the/DT firm/NN)
#   ’/NNP
#   s/VBD
#   iPhones/NNS
#   ./.)

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint
iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('Samsung', 'NNP', 'O'),
#  ('told', 'VBD', 'O'),
#  ('owners', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('Galaxy', 'NNP', 'O'),
#  ('Note', 'NNP', 'O'),
#  ('4', 'CD', 'O'),
#  ('phone', 'NN', 'B-NP'),
#  ('to', 'TO', 'O'),
#  ('install', 'VB', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('new', 'JJ', 'I-NP'),
#  ('version', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('Google', 'NNP', 'O'),
#  ('’', 'NNP', 'O'),
#  ('s', 'VBD', 'O'),
#  ('Android', 'NNP', 'O'),
#  ('operating', 'VBG', 'O'),
#  ('system', 'NN', 'B-NP'),
#  ('intended', 'VBN', 'O'),
#  ('for', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('more', 'RBR', 'O'),
#  ('recent', 'JJ', 'O'),
#  ('Galaxy', 'NNP', 'O'),
#  ('Note', 'NNP', 'O'),
#  ('7', 'CD', 'O'),
#  (',', ',', 'O'),
#  ('but', 'CC', 'O'),
#  ('which', 'WDT', 'O'),
#  ('users', 'NNS', 'O'),
#  ('claimed', 'VBD', 'O'),
#  ('rendered', 'VBD', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('old', 'JJ', 'I-NP'),
#  ('model', 'NN', 'I-NP'),
#  ('sluggish', 'JJ', 'O'),
#  ('.', '.', 'O'),
#  ('Likewise', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Apple', 'NNP', 'O'),
#  ('told', 'VBD', 'O'),
#  ('iPhone', 'NN', 'B-NP'),
#  ('6', 'CD', 'O'),
#  ('owners', 'NNS', 'O'),
#  ('to', 'TO', 'O'),
#  ('install', 'VB', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ('operating', 'NN', 'I-NP'),
#  ('system', 'NN', 'B-NP'),
#  ('designed', 'VBN', 'O'),
#  ('for', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('iPhone', 'NN', 'I-NP'),
#  ('7', 'CD', 'O'),
#  (',', ',', 'O'),
#  ('leading', 'VBG', 'O'),
#  ('to', 'TO', 'O'),
#  ('problems', 'NNS', 'O'),
#  ('for', 'IN', 'O'),
#  ('owners', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('older', 'JJR', 'O'),
#  ('model', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('Both', 'DT', 'O'),
#  ('firms', 'NNS', 'O'),
#  ('were', 'VBD', 'O'),
#  ('issued', 'VBN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('maximum', 'JJ', 'I-NP'),
#  ('fine', 'NN', 'I-NP'),
#  ('of', 'IN', 'O'),
#  ('€5m', 'NNP', 'O'),
#  ('each', 'DT', 'O'),
#  ('and', 'CC', 'O'),
#  ('ordered', 'VBD', 'O'),
#  ('to', 'TO', 'O'),
#  ('display', 'VB', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('notice', 'NN', 'I-NP'),
#  ('on', 'IN', 'O'),
#  ('their', 'PRP$', 'O'),
#  ('Italian', 'JJ', 'O'),
#  ('websites', 'NNS', 'O'),
#  ('informing', 'VBG', 'O'),
#  ('customers', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('watchdog', 'NN', 'I-NP'),
#  ('’', 'NNP', 'O'),
#  ('s', 'NN', 'B-NP'),
#  ('decision', 'NN', 'B-NP'),
#  ('.', '.', 'O'),
#  ('Apple', 'NNP', 'O'),
#  ('was', 'VBD', 'O'),
#  ('fined', 'VBN', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ('additional', 'JJ', 'I-NP'),
#  ('€5m', 'NN', 'I-NP'),
#  ('for', 'IN', 'O'),
#  ('failing', 'VBG', 'O'),
#  ('to', 'TO', 'O'),
#  ('give', 'VB', 'O'),
#  ('customers', 'NNS', 'O'),
#  ('clear', 'JJ', 'B-NP'),
#  ('information', 'NN', 'I-NP'),
#  ('about', 'IN', 'O'),
#  ('“', 'NNP', 'O'),
#  ('essential', 'JJ', 'O'),
#  ('”', 'NNP', 'O'),
#  ('characteristics', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('lithium', 'NN', 'B-NP'),
#  ('batteries', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('including', 'VBG', 'O'),
#  ('their', 'PRP$', 'O'),
#  ('average', 'JJ', 'B-NP'),
#  ('life', 'NN', 'I-NP'),
#  ('expectancy', 'NN', 'B-NP'),
#  (',', ',', 'O'),
#  ('how', 'WRB', 'O'),
#  ('to', 'TO', 'O'),
#  ('maintain', 'VB', 'O'),
#  ('them', 'PRP', 'O'),
#  ('or', 'CC', 'O'),
#  ('eventually', 'RB', 'O'),
#  ('replace', 'VB', 'O'),
#  ('them', 'PRP', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('firm', 'NN', 'I-NP'),
#  ('’', 'NNP', 'O'),
#  ('s', 'VBD', 'O'),
#  ('iPhones', 'NNS', 'O'),
#  ('.', '.', 'O')]

# %%
ne_tree = nltk.ne_chunk(t1)
print(ne_tree)
# Out:
# (S
#   (PERSON Samsung/NNP)
#   told/VBD
#   owners/NNS
#   of/IN
#   its/PRP$
#   (PERSON Galaxy/NNP Note/NNP)
#   4/CD
#   phone/NN
#   to/TO
#   install/VB
#   a/DT
#   new/JJ
#   version/NN
#   of/IN
#   (PERSON Google/NNP)
#   ’/NNP
#   s/VBD
#   (PERSON Android/NNP)
#   operating/VBG
#   system/NN
#   intended/VBN
#   for/IN
#   the/DT
#   more/RBR
#   recent/JJ
#   (PERSON Galaxy/NNP Note/NNP)
#   7/CD
#   ,/,
#   but/CC
#   which/WDT
#   users/NNS
#   claimed/VBD
#   rendered/VBD
#   the/DT
#   old/JJ
#   model/NN
#   sluggish/JJ
#   ./.
#   (PERSON Likewise/NNP)
#   ,/,
#   (PERSON Apple/NNP)
#   told/VBD
#   (ORGANIZATION iPhone/NN)
#   6/CD
#   owners/NNS
#   to/TO
#   install/VB
#   an/DT
#   operating/NN
#   system/NN
#   designed/VBN
#   for/IN
#   the/DT
#   (ORGANIZATION iPhone/NN)
#   7/CD
#   ,/,
#   leading/VBG
#   to/TO
#   problems/NNS
#   for/IN
#   owners/NNS
#   of/IN
#   the/DT
#   older/JJR
#   model/NN
#   ./.
#   Both/DT
#   firms/NNS
#   were/VBD
#   issued/VBN
#   the/DT
#   maximum/JJ
#   fine/NN
#   of/IN
#   €5m/NNP
#   each/DT
#   and/CC
#   ordered/VBD
#   to/TO
#   display/VB
#   a/DT
#   notice/NN
#   on/IN
#   their/PRP$
#   (GPE Italian/JJ)
#   websites/NNS
#   informing/VBG
#   customers/NNS
#   of/IN
#   the/DT
#   watchdog/NN
#   ’/NNP
#   s/NN
#   decision/NN
#   ./.
#   (PERSON Apple/NNP)
#   was/VBD
#   fined/VBN
#   an/DT
#   additional/JJ
#   €5m/NN
#   for/IN
#   failing/VBG
#   to/TO
#   give/VB
#   customers/NNS
#   clear/JJ
#   information/NN
#   about/IN
#   “/NNP
#   essential/JJ
#   ”/NNP
#   characteristics/NNS
#   of/IN
#   lithium/NN
#   batteries/NNS
#   ,/,
#   including/VBG
#   their/PRP$
#   average/JJ
#   life/NN
#   expectancy/NN
#   ,/,
#   how/WRB
#   to/TO
#   maintain/VB
#   them/PRP
#   or/CC
#   eventually/RB
#   replace/VB
#   them/PRP
#   in/IN
#   the/DT
#   firm/NN
#   ’/NNP
#   s/VBD
#   (ORGANIZATION iPhones/NNS)
#   ./.)

# %%
def preprocess_v2(text):
    from nltk.tokenize import RegexpTokenizer

    tokenizer = RegexpTokenizer(r'\w+')
    word_list = tokenizer.tokenize(text)
    word_tags = pos_tag(word_list)
    
    return word_list, word_tags

# %%
l2, t2 = preprocess_v2(demo1)

# %%
l2
# Out:
# ['Samsung',
#  'told',
#  'owners',
#  'of',
#  'its',
#  'Galaxy',
#  'Note',
#  '4',
#  'phone',
#  'to',
#  'install',
#  'a',
#  'new',
#  'version',
#  'of',
#  'Google',
#  's',
#  'Android',
#  'operating',
#  'system',
#  'intended',
#  'for',
#  'the',
#  'more',
#  'recent',
#  'Galaxy',
#  'Note',
#  '7',
#  'but',
#  'which',
#  'users',
#  'claimed',
#  'rendered',
#  'the',
#  'old',
#  'model',
#  'sluggish',
#  'Likewise',
#  'Apple',
#  'told',
#  'iPhone',
#  '6',
#  'owners',
#  'to',
#  'install',
#  'an',
#  'operating',
#  'system',
#  'designed',
#  'for',
#  'the',
#  'iPhone',
#  '7',
#  'leading',
#  'to',
#  'problems',
#  'for',
#  'owners',
#  'of',
#  'the',
#  'older',
#  'model',
#  'Both',
#  'firms',
#  'were',
#  'issued',
#  'the',
#  'maximum',
#  'fine',
#  'of',
#  '5m',
#  'each',
#  'and',
#  'ordered',
#  'to',
#  'display',
#  'a',
#  'notice',
#  'on',
#  'their',
#  'Italian',
#  'websites',
#  'informing',
#  'customers',
#  'of',
#  'the',
#  'watchdog',
#  's',
#  'decision',
#  'Apple',
#  'was',
#  'fined',
#  'an',
#  'additional',
#  '5m',
#  'for',
#  'failing',
#  'to',
#  'give',
#  'customers',
#  'clear',
#  'information',
#  'about',
#  'essential',
#  'characteristics',
#  'of',
#  'lithium',
#  'batteries',
#  'including',
#  'their',
#  'average',
#  'life',
#  'expectancy',
#  'how',
#  'to',
#  'maintain',
#  'them',
#  'or',
#  'eventually',
#  'replace',
#  'them',
#  'in',
#  'the',
#  'firm',
#  's',
#  'iPhones']

# %%
t2
# Out:
# [('Samsung', 'NNP'),
#  ('told', 'VBD'),
#  ('owners', 'NNS'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('Galaxy', 'NNP'),
#  ('Note', 'NNP'),
#  ('4', 'CD'),
#  ('phone', 'NN'),
#  ('to', 'TO'),
#  ('install', 'VB'),
#  ('a', 'DT'),
#  ('new', 'JJ'),
#  ('version', 'NN'),
#  ('of', 'IN'),
#  ('Google', 'NNP'),
#  ('s', 'FW'),
#  ('Android', 'NNP'),
#  ('operating', 'VBG'),
#  ('system', 'NN'),
#  ('intended', 'VBN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('more', 'RBR'),
#  ('recent', 'JJ'),
#  ('Galaxy', 'NNP'),
#  ('Note', 'NNP'),
#  ('7', 'CD'),
#  ('but', 'CC'),
#  ('which', 'WDT'),
#  ('users', 'NNS'),
#  ('claimed', 'VBD'),
#  ('rendered', 'VBD'),
#  ('the', 'DT'),
#  ('old', 'JJ'),
#  ('model', 'NN'),
#  ('sluggish', 'JJ'),
#  ('Likewise', 'NNP'),
#  ('Apple', 'NNP'),
#  ('told', 'VBD'),
#  ('iPhone', 'NN'),
#  ('6', 'CD'),
#  ('owners', 'NNS'),
#  ('to', 'TO'),
#  ('install', 'VB'),
#  ('an', 'DT'),
#  ('operating', 'NN'),
#  ('system', 'NN'),
#  ('designed', 'VBN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('iPhone', 'NN'),
#  ('7', 'CD'),
#  ('leading', 'VBG'),
#  ('to', 'TO'),
#  ('problems', 'NNS'),
#  ('for', 'IN'),
#  ('owners', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('older', 'JJR'),
#  ('model', 'NN'),
#  ('Both', 'DT'),
#  ('firms', 'NNS'),
#  ('were', 'VBD'),
#  ('issued', 'VBN'),
#  ('the', 'DT'),
#  ('maximum', 'JJ'),
#  ('fine', 'NN'),
#  ('of', 'IN'),
#  ('5m', 'CD'),
#  ('each', 'DT'),
#  ('and', 'CC'),
#  ('ordered', 'VBD'),
#  ('to', 'TO'),
#  ('display', 'VB'),
#  ('a', 'DT'),
#  ('notice', 'NN'),
#  ('on', 'IN'),
#  ('their', 'PRP$'),
#  ('Italian', 'JJ'),
#  ('websites', 'NNS'),
#  ('informing', 'VBG'),
#  ('customers', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('watchdog', 'NN'),
#  ('s', 'JJ'),
#  ('decision', 'NN'),
#  ('Apple', 'NNP'),
#  ('was', 'VBD'),
#  ('fined', 'VBN'),
#  ('an', 'DT'),
#  ('additional', 'JJ'),
#  ('5m', 'CD'),
#  ('for', 'IN'),
#  ('failing', 'VBG'),
#  ('to', 'TO'),
#  ('give', 'VB'),
#  ('customers', 'NNS'),
#  ('clear', 'JJ'),
#  ('information', 'NN'),
#  ('about', 'IN'),
#  ('essential', 'JJ'),
#  ('characteristics', 'NNS'),
#  ('of', 'IN'),
#  ('lithium', 'NN'),
#  ('batteries', 'NNS'),
#  ('including', 'VBG'),
#  ('their', 'PRP$'),
#  ('average', 'JJ'),
#  ('life', 'NN'),
#  ('expectancy', 'NN'),
#  ('how', 'WRB'),
#  ('to', 'TO'),
#  ('maintain', 'VB'),
#  ('them', 'PRP'),
#  ('or', 'CC'),
#  ('eventually', 'RB'),
#  ('replace', 'VB'),
#  ('them', 'PRP'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('firm', 'NN'),
#  ('s', 'VBD'),
#  ('iPhones', 'NNS')]

# %% [markdown]
# # Named Entity Recognition with Spacy

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc = nlp(demo1)

# %%
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('\n', 'GPE'),
#  ('Samsung', 'ORG'),
#  ('Galaxy Note', 'ORG'),
#  ('4', 'CARDINAL'),
#  ('Google’s', 'PRODUCT'),
#  ('Android', 'FAC'),
#  ('Galaxy Note', 'PRODUCT'),
#  ('Apple', 'ORG'),
#  ('iPhone', 'ORG'),
#  ('6', 'CARDINAL'),
#  ('the iPhone 7', 'ORG'),
#  ('€5m', 'MONEY'),
#  ('Italian', 'NORP'),
#  ('Apple', 'ORG'),
#  ('an additional €5m', 'MONEY'),
#  ('iPhones', 'GPE'),
#  ('\n', 'GPE')]

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(
# , 'B', 'GPE'),
#  (Samsung, 'B', 'ORG'),
#  (told, 'O', ''),
#  (owners, 'O', ''),
#  (of, 'O', ''),
#  (its, 'O', ''),
#  (Galaxy, 'B', 'ORG'),
#  (Note, 'I', 'ORG'),
#  (4, 'B', 'CARDINAL'),
#  (phone, 'O', ''),
#  (to, 'O', ''),
#  (install, 'O', ''),
#  (a, 'O', ''),
#  (new, 'O', ''),
#  (version, 'O', ''),
#  (of, 'O', ''),
#  (Google, 'B', 'PRODUCT'),
#  (’s, 'I', 'PRODUCT'),
#  (Android, 'B', 'FAC'),
#  (operating, 'O', ''),
#  (system, 'O', ''),
#  (intended, 'O', ''),
#  (for, 'O', ''),
#  (the, 'O', ''),
#  (more, 'O', ''),
#  (recent, 'O', ''),
#  (Galaxy, 'B', 'PRODUCT'),
#  (Note, 'I', 'PRODUCT'),
#  (7, 'O', ''),
#  (,, 'O', ''),
#  (but, 'O', ''),
#  (which, 'O', ''),
#  (users, 'O', ''),
#  (claimed, 'O', ''),
#  (rendered, 'O', ''),
#  (the, 'O', ''),
#  (old, 'O', ''),
#  (model, 'O', ''),
#  (sluggish, 'O', ''),
#  (., 'O', ''),
#  (
#
# , 'O', ''),
#  (Likewise, 'O', ''),
#  (,, 'O', ''),
#  (Apple, 'B', 'ORG'),
#  (told, 'O', ''),
#  (iPhone, 'B', 'ORG'),
#  (6, 'B', 'CARDINAL'),
#  (owners, 'O', ''),
#  (to, 'O', ''),
#  (install, 'O', ''),
#  (an, 'O', ''),
#  (operating, 'O', ''),
#  (system, 'O', ''),
#  (designed, 'O', ''),
#  (for, 'O', ''),
#  (the, 'B', 'ORG'),
#  (iPhone, 'I', 'ORG'),
#  (7, 'I', 'ORG'),
#  (,, 'O', ''),
#  (leading, 'O', ''),
#  (to, 'O', ''),
#  (problems, 'O', ''),
#  (for, 'O', ''),
#  (owners, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (older, 'O', ''),
#  (model, 'O', ''),
#  (., 'O', ''),
#  (
#
# , 'O', ''),
#  (Both, 'O', ''),
#  (firms, 'O', ''),
#  (were, 'O', ''),
#  (issued, 'O', ''),
#  (the, 'O', ''),
#  (maximum, 'O', ''),
#  (fine, 'O', ''),
#  (of, 'O', ''),
#  (€, 'B', 'MONEY'),
#  (5, 'I', 'MONEY'),
#  (m, 'I', 'MONEY'),
#  (each, 'O', ''),
#  (and, 'O', ''),
#  (ordered, 'O', ''),
#  (to, 'O', ''),
#  (display, 'O', ''),
#  (a, 'O', ''),
#  (notice, 'O', ''),
#  (on, 'O', ''),
#  (their, 'O', ''),
#  (Italian, 'B', 'NORP'),
#  (websites, 'O', ''),
#  (informing, 'O', ''),
#  (customers, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (watchdog, 'O', ''),
#  (’s, 'O', ''),
#  (decision, 'O', ''),
#  (., 'O', ''),
#  (
#
# , 'O', ''),
#  (Apple, 'B', 'ORG'),
#  (was, 'O', ''),
#  (fined, 'O', ''),
#  (an, 'B', 'MONEY'),
#  (additional, 'I', 'MONEY'),
#  (€, 'I', 'MONEY'),
#  (5, 'I', 'MONEY'),
#  (m, 'I', 'MONEY'),
#  (for, 'O', ''),
#  (failing, 'O', ''),
#  (to, 'O', ''),
#  (give, 'O', ''),
#  (customers, 'O', ''),
#  (clear, 'O', ''),
#  (information, 'O', ''),
#  (about, 'O', ''),
#  (“, 'O', ''),
#  (essential, 'O', ''),
#  (”, 'O', ''),
#  (characteristics, 'O', ''),
#  (of, 'O', ''),
#  (lithium, 'O', ''),
#  (batteries, 'O', ''),
#  (,, 'O', ''),
#  (including, 'O', ''),
#  (their, 'O', ''),
#  (average, 'O', ''),
#  (life, 'O', ''),
#  (expectancy, 'O', ''),
#  (,, 'O', ''),
#  (how, 'O', ''),
#  (to, 'O', ''),
#  (maintain, 'O', ''),
#  (them, 'O', ''),
#  (or, 'O', ''),
#  (eventually, 'O', ''),
#  (replace, 'O', ''),
#  (them, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (firm, 'O', ''),
#  (’s, 'O', ''),
#  (iPhones, 'B', 'GPE'),
#  (., 'O', ''),
#  (
# , 'B', 'GPE')]

# %%
#passing the sentences
displacy.render(nlp(str(demo1)), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Samsung
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  told owners of its
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Galaxy Note
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  phone to install a new version of
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Google’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Android
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  operating system intended for the more recent
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Galaxy Note
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  7, but which users claimed rendered the old model sluggish.</br></br>Likewise,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  told
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     iPhone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  owners to install an operating system designed for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the iPhone 7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , leading to problems for owners of the older model.</br></br>Both firms were issued the maximum fine of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     €5m
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  each and ordered to display a notice on their
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Italian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  websites informing customers of the watchdog’s decision.</br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was fined
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     an additional €5m
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  for failing to give customers clear information about “essential” characteristics of lithium batteries, including their average life expectancy, how to maintain them or eventually replace them in the firm’s
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     iPhones
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div>

# %%
#passing the word list for same sentences
displacy.render(nlp(str(l2)), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5">['
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Samsung
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ', 'told', 'owners', 'of', 'its', '
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Galaxy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ', 'Note', '4', 'phone', 'to', 'install', 'a', 'new', 'version', 'of', '
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ', 's', '
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Android
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ', 'operating', 'system', 'intended', 'for', 'the', 'more', 'recent', '
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Galaxy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ', 'Note', '7', 'but', 'which', 'users', 'claimed', 'rendered', 'the', 'old', 'model', 'sluggish', 'Likewise', '
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ', 'told', '
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     iPhone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ', '6', 'owners', 'to', 'install', 'an', 'operating', 'system', 'designed', 'for', 'the', '
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     iPhone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ', '7', 'leading', 'to', 'problems', 'for', 'owners', 'of', 'the', 'older', 'model', 'Both', 'firms', 'were', 'issued', 'the', 'maximum', 'fine', 'of', '
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     5m'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# , 'each', 'and', 'ordered', 'to', 'display', 'a', 'notice', 'on', 'their', '
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Italian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# ', 'websites', 'informing', 'customers', 'of', 'the', 'watchdog', 's', 'decision', '
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ', 'was', 'fined', 'an', 'additional', '
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     5m
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ', 'for', 'failing', 'to', 'give', 'customers', 'clear', 'information', 'about', 'essential', 'characteristics', 'of', 'lithium', 'batteries', 'including', 'their', 'average', 'life', 'expectancy', 'how', 'to', 'maintain', 'them', 'or', 'eventually', 'replace', 'them', 'in', 'the', 'firm', 's', '
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     iPhones
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ']</div>
